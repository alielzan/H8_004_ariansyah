# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Polygon
# %matplotlib inline
from scipy import integrate

# Define function g
def g(x):
    return 3 * x**2 - 6 * x + 3 

# Create an array of x values from 0 to 10
x = range(0, 10)

# Get the corresponding y values from the function
y = [g(a) for a in x]

# Set up the plot
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# Plot x against g(x)
plt.plot(x,y, color='green')

# Make the shaded region
ix = np.linspace(0, 3)
iy = g(ix)
verts = [(0, 0)] + list(zip(ix, iy)) + [(3, 0)]
poly = Polygon(verts, facecolor='orange')
ax.add_patch(poly)

plt.show()

# %%
verts
# Out:
# [(0, 0),
#  (0.0, 3.0),
#  (0.061224489795918366, 2.6438983756768013),
#  (0.12244897959183673, 2.3102873802582256),
#  (0.18367346938775508, 1.9991670137442732),
#  (0.24489795918367346, 1.710537276134944),
#  (0.30612244897959184, 1.4443981674302373),
#  (0.36734693877551017, 1.2007496876301542),
#  (0.42857142857142855, 0.9795918367346941),
#  (0.4897959183673469, 0.7809246147438569),
#  (0.5510204081632653, 0.6047480216576426),
#  (0.6122448979591837, 0.45106205747605177),
#  (0.673469387755102, 0.31986672219908385),
#  (0.7346938775510203, 0.21116201582673888),
#  (0.7959183673469388, 0.1249479383590173),
#  (0.8571428571428571, 0.06122448979591866),
#  (0.9183673469387755, 0.01999167013744252),
#  (0.9795918367346939, 0.001249479383590657),
#  (1.0408163265306123, 0.004997917534360852),
#  (1.1020408163265305, 0.03123698458975399),
#  (1.163265306122449, 0.07996668054977185),
#  (1.2244897959183674, 0.15118700541441044),
#  (1.2857142857142856, 0.24489795918367285),
#  (1.346938775510204, 0.36109954185756),
#  (1.4081632653061225, 0.4997917534360674),
#  (1.4693877551020407, 0.6609745939191995),
#  (1.530612244897959, 0.8446480633069555),
#  (1.5918367346938775, 1.0508121615993335),
#  (1.653061224489796, 1.2794668887963354),
#  (1.7142857142857142, 1.5306122448979593),
#  (1.7755102040816326, 1.8042482299042053),
#  (1.836734693877551, 2.100374843815077),
#  (1.8979591836734693, 2.4189920866305705),
#  (1.9591836734693877, 2.760099958350688),
#  (2.020408163265306, 3.1236984589754258),
#  (2.0816326530612246, 3.509787588504791),
#  (2.142857142857143, 3.9183673469387728),
#  (2.204081632653061, 4.349437734277382),
#  (2.2653061224489797, 4.802998750520615),
#  (2.326530612244898, 5.279050395668474),
#  (2.387755102040816, 5.777592669720947),
#  (2.4489795918367347, 6.29862557267805),
#  (2.510204081632653, 6.8421491045397715),
#  (2.571428571428571, 7.4081632653061185),
#  (2.63265306122449, 7.996668054977093),
#  (2.693877551020408, 8.607663473552687),
#  (2.7551020408163263, 9.241149521032899),
#  (2.816326530612245, 9.897126197417741),
#  (2.877551020408163, 10.575593502707203),
#  (2.9387755102040813, 11.276551436901286),
#  (3.0, 12.0),
#  (3, 0)]

# %%
i, e = integrate.quad(lambda x: 3 * x**2 - 6 * x + 3, 0, 3)
print(i, e)
# Out:
# 9.0 9.992007221626409e-14

# %%
print(e)
# Out:
# 9.992007221626409e-14

# %%
# Define function g
def g(x):
    return 8 * x**3 - x**2 + 5 * x - 1  

# Create an array of x values from 0 to 10
x = range(0, 10)

# Get the corresponding y values from the function
y = [g(a) for a in x]

# Set up the plot
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# Plot x against g(x)
plt.plot(x,y, color='green')

# Make the shaded region
ix = np.linspace(0, 3)
iy = g(ix)
verts = [(0, 0)] + list(zip(ix, iy)) + [(3, 0)]
poly = Polygon(verts, facecolor='orange')
ax.add_patch(poly)

# %%
verts
# Out:
# [(0, 0),
#  (0.0, -1.0),
#  (0.061224489795918366, -0.6957900194646789),
#  (0.12244897959183673, -0.3880610969918996),
#  (0.18367346938775508, -0.0657974143426634),
#  (0.24489795918367346, 0.2820168467220292),
#  (0.30612244897959184, 0.666397504441177),
#  (0.36734693877551017, 1.0983603770537784),
#  (0.42857142857142855, 1.5889212827988337),
#  (0.4897959183673469, 2.1490960399153414),
#  (0.5510204081632653, 2.7899004666422997),
#  (0.6122448979591837, 3.5223503812187102),
#  (0.673469387755102, 4.357461601883569),
#  (0.7346938775510203, 5.306249946875875),
#  (0.7959183673469388, 6.379731234434632),
#  (0.8571428571428571, 7.588921282798832),
#  (0.9183673469387755, 8.944835910207482),
#  (0.9795918367346939, 10.458490934899574),
#  (1.0408163265306123, 12.14090217511411),
#  (1.1020408163265305, 14.003085449090086),
#  (1.163265306122449, 16.05605657506651),
#  (1.2244897959183674, 18.310831371282376),
#  (1.2857142857142856, 20.778425655976672),
#  (1.346938775510204, 23.469855247388416),
#  (1.4081632653061225, 26.3961359637566),
#  (1.4693877551020407, 29.56828362332021),
#  (1.530612244897959, 32.997314044318266),
#  (1.5918367346938775, 36.69424304498976),
#  (1.653061224489796, 40.67008644357368),
#  (1.7142857142857142, 44.93586005830903),
#  (1.7755102040816326, 49.502579707434826),
#  (1.836734693877551, 54.38126120919005),
#  (1.8979591836734693, 59.58292038181369),
#  (1.9591836734693877, 65.11857304354477),
#  (2.020408163265306, 70.99923501262228),
#  (2.0816326530612246, 77.23592210728523),
#  (2.142857142857143, 83.8396501457726),
#  (2.204081632653061, 90.82143494632336),
#  (2.2653061224489797, 98.19229232717662),
#  (2.326530612244898, 105.96323810657123),
#  (2.387755102040816, 114.14528810274626),
#  (2.4489795918367347, 122.74945813394079),
#  (2.510204081632653, 131.78676401839368),
#  (2.571428571428571, 141.26822157434398),
#  (2.63265306122449, 151.20484662003076),
#  (2.693877551020408, 161.60765497369295),
#  (2.7551020408163263, 172.48766245356947),
#  (2.816326530612245, 183.85588487789954),
#  (2.877551020408163, 195.7233380649219),
#  (2.9387755102040813, 208.1010378328757),
#  (3.0, 221.0),
#  (3, 0)]

# %%
i, e = integrate.quad(lambda x: 8 * x**3 - x**2 + 5 * x - 1, 0, 3)
print(i, e)
# Out:
# 172.5 1.9172565526794584e-12

# %%
print(e)
# Out:
# 1.9172565526794584e-12
